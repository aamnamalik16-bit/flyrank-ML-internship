# %% [markdown]
# <a href="https://colab.research.google.com/github/aamnamalik16-bit/flyrank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aamnamalik16-bit/flyrank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Lane: Refresh Priority Prediction
#
# I chose the Refresh Priority Prediction lane because websites contain many pages, but not all of them need updating at the same time. My goal is to identify pages that are more likely to lose performance so content teams can refresh them first. This can help save time and improve content management by focusing on pages that need attention the most.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My project helps content managers decide which pages should be refreshed first. The action is to review and update the selected pages before their performance drops further. If the recommendation is wrong, time may be wasted updating pages that do not need changes, while important pages may continue to lose traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Three real numbers from the starter data:
#
# There are 30,000 content items across 32 clients — enough scale for a meaningful query signal analysis.
# 54.2% of pages (16,262 out of 30,000) show a declining trend — meaning more than half the content inventory may need attention at any given time.
# Average CTR is only 0.51% despite an average of 5,200 impressions per page — most pages are getting visibility but failing to capture clicks, which is exactly the kind of gap query-level analysis can help explain.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os

# Clone the repo
# !git clone https://github.com/aamnamalik16-bit/flyrank-ML-internship.git

# Move into the repo folder
os.chdir('flyrank-ML-internship')

# Verify the file exists
# !ls data/raw/
# Out:
# Cloning into 'flyrank-ML-internship'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 143 (delta 56), reused 111 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 1.84 MiB | 17.81 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

print("Total content items:", len(df))
print("Number of clients:", df['client_id'].nunique())
print("Declining pages (trend_direction == down):", (df['trend_direction'] == 'down').sum())
print("% declining:", round((df['trend_direction'] == 'down').mean() * 100, 1), "%")
print("Avg impressions (90d):", round(df['impressions_90d'].mean(), 1))
print("Avg CTR:", round(df['ctr'].mean(), 4))
# Out:
# Total content items: 30000
# Number of clients: 32
# Declining pages (trend_direction == down): 16262
# % declining: 54.2 %
# Avg impressions (90d): 5200.4
# Avg CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# What this work can claim:
#
# I can say which query signals are observed to be associated with higher clicks or impressions — directional, measured findings.
# I can produce a decision-support ranking — a prioritized list of pages where query patterns suggest optimization opportunity.
# I can say "pages with these query characteristics tend to have lower CTR" — an observed pattern, not a causal proof.
#
# What this work cannot claim:
#
# I cannot claim that optimizing a page for a query will cause traffic to recover — that would require a controlled experiment.
# I cannot claim to know Google's ranking algorithm — I only observe outcomes, not the mechanism behind them.
# I cannot claim my rankings are perfect — they are directional recommendations for a human reviewer to act on.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
